# %%
from vision_proccessing import *
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20,20)
def main():
    gray= convert_to_gray('../images/left1.png')
    print(gray.shape)
    #gray= convert_to_gray('test_image.jpg')
    gradient = convert_to_gradient(gray)
    hough = hough_space(gradient,2,1,100,5)
    display = display_lines(hough,gray)
    #cv2.imshow('result', display)
    plt.subplot(121)
    plt.imshow(gray)
    plt.subplot(122)
    plt.imshow(display, cmap='gray')
    #cv2.waitKey(0)
    #cv2.destroyAllWindows()

main()
# Out:
# (2160, 4096)

# %%
from vision_proccessing import *
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20,20)
def main():
    color = convert_to_gray('../images/left1.png')
    print(color.shape)
    plt.imshow(color)
    
main()
# Out:
# (2160, 4096)
